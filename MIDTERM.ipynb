# %% [markdown]
# <a href="https://colab.research.google.com/github/tanashoooo/SF251/blob/main/MIDTERM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW4 - Data Cleaning and Regex
# ## DUE: 19th Feb 2026
#
# - There are 12 questions in this homework. 3 poitns total.
# - Data for this homework can be found [HW4.zip](https://github.com/yongsa-nut/SF251_67_2/blob/main/data/HW4.zip)

# %% [markdown]
# ## Regex Practices
#
# - Run the code below so you can check your answers.

# %%
import re

# function to check your regex
def test_regex(pattern, test_cases, expected_results, match_type='full'):
    print(f"Testing pattern: {pattern}")

    for i, (test, expected) in enumerate(zip(test_cases, expected_results), 1):
        if match_type == 'full':
            result = bool(re.fullmatch(pattern, test))
            match_text = 'matches' if result else 'does not match'
        elif match_type == 'search':
            result = bool(re.search(pattern, test))
            match_text = 'contains match' if result else 'does not contain match'

        print(f"Test {i}: {'✓' if result == expected else '✗'} - '{test}' {match_text}")

        if match_type == 'search' and result:
            matches = re.findall(pattern, test)
            print(f"   Matches found: {matches}")

    print()

# %% [markdown]
# ## Q1a - Uppercase and lowercase only
#
# Write a regular expression to match a string that contains only uppercase and lowercase letters (no numbers or special characters).
#
# - Match: HelloWorld, abcDEF, RegexPractice
# - Not match: Hello123, Special@Characters, With Spaces

# %%
pattern_1a = r"..."  # Fill in your regex here

## Test cases
test_cases_1a = ["HelloWorld", "abcDEF", "RegexPractice", "Hello123", "Special@Characters", "With Spaces"]
expected_1a = [True, True, True, False, False, False]
test_regex(pattern_1a, test_cases_1a, expected_1a)

# %% [markdown]
# ### Q1b - Zip codes
# Create a regex pattern to match a zip code in the format xxxxx or xxxxx-xxxx, where x represents a digit.
#
# - Match: 12345, 12345-6789
# - Not match: 1234, 123, 123456, 12345-678

# %%
pattern_1b = r"..."  # Fill in your regex here

## Test cases
test_cases_1b = ["12345", "12345-6789", "1234", "123", "123456", "12345-678"]
expected_1b = [True, True, False, False, False, False]
test_regex(pattern_1b, test_cases_1b, expected_1b)

# %% [markdown]
# ### Q1c - Time
#
# Develop a regex pattern to match a time in 24-hour format (HH:MM), where HH is between 00 and 23, and MM is between 00 and 59.
#
# - Match: 13:45, 00:00, 23:59
# - Not match: 24:00, 12:60, 1:30

# %%
pattern_1c = r"..."  # Fill in your regex here

## Test cases
test_cases_1c = ["13:45", "00:00", "23:59", "24:00", "12:60", "1:30"]
expected_1c = [True, True, True, False, False, False]
test_regex(pattern_1c, test_cases_1c, expected_1c)

# %% [markdown]
# ### Q1d - username
#
# Write a regular expression to match a string that contains only lowercase letters and underscores, starts with a letter, and is between 3 and 16 characters long.
#
# - Match: hello_world, a_b_c
# - Not match: username_123, _hello, ab, abcdefghijklmnopq

# %%
pattern_1d = r"..."  # Fill in your regex here

## Test cases
test_cases_1d = ["hello_world", "a_b_c" "username_123", "_hello", "ab", "abcdefghijklmnopq"]
expected_1d = [True, True, False, False, False, False]
test_regex(pattern_1d, test_cases_1d, expected_1d)

# %% [markdown]
# ### Q1e - Apple or Orange
#
# Create a regex pattern to find the word "apple" or "orange" in a sentence.
#
# - Match: "I prefer apple juice over orange juice." (Match: apple, orange), "The orange cat played with an apple." (Match: orange, apple)
#
# - Not Match: "Pineapple is my favorite fruit.", "He wore an oran shirt."

# %%
pattern_1e = r"..."  # Fill in your regex here

## Test cases
test_cases_1e = [
            "I prefer apple juice over orange juice.",
            "The orange cat played with an apple.",
            "Pineapple is my favorite fruit.",
            "He wore an oran shirt."
               ]
expected_1e = [True, True, False, False]
test_regex(pattern_1e, test_cases_1e, expected_1e,'search')

# %% [markdown]
# ---

# %% [markdown]
# ## TSE Training Program
#
# สำหรับ data ที่สองนั้น เป็น data มาจาก TSE Training Program: Introduction to Modern Information Techonology ที่เกิดขึ้นไปในวันที่ 29 เมษายน - 2 พฤษภาคม ที่ผ่านมาที่ภาคของเรา ซึ่งโปรแกรมนี้นั้นมีเด็กมัธยม 77 คนมาเข้าร่วม (ไม่ได้ตอบแบบสอบถามทุกคน) และแบ่งเป็นสองกลุ่ม กลุ่มภาษาไทย กับ กลุ่มภาษาอังกฤษ ดังนั้นเราจึงมีข้อมูลสองอัน ภาษาไทยอันหนึ่ง และภาษาอังกฤษอีกอันหนึ่ง
#
# ข้อมูลที่ได้มานั้น ทางโครงการ TEP/TEPE เป็นคนจัดเก็บไว้หลังจากเสร็จงาน
#
# ในการจัดอบรมนี้นั้นมีหลายโปรแกรมด้วยกัน ประกอบไปด้วย
# 1) การเสวนาหัวข้อ Intro to Modern IT
# 2) หัวข้อ TSE Showcase
# 3) การดูงานนอกสถานที่
# 4) กิจกรรม Workshop
#
# ส่วนที่เราสนใจนั้นคือ Workshop ซึ่ง เราต้องการทราบว่า นักเรียนมีความพึ่งพอใจแค่ไหน
# ดังนั้นข้อมูลที่เราต้องการรู้มีสามอย่างคือ
# 1) กิจกรรม workshop (Workshop activity)
# 2) การถ่ายทอดของผู้สอน/ผู้บรรยาย (The instructors/lecturers are performance)
# 3) ผลที่่ได้รับที่ได้รับจากการอบรม ตรงตามที่คาดหวัง (The TSE training objectives were met.)
#
# หมายเหตุ: ข้อมูลที่นำมาใช้ได้มีการลบข้อมูลส่วนบุคคลออกหมดแล้ว

# %%
import pandas as pd
from plotnine import *

# %%
# !wget https://github.com/yongsa-nut/SF251_67_2/raw/refs/heads/main/data/HW4.zip
# !unzip 'HW4.zip'
# Out:
# --2026-02-24 18:21:05--  https://github.com/yongsa-nut/SF251_67_2/raw/refs/heads/main/data/HW4.zip
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/yongsa-nut/SF251_67_2/refs/heads/main/data/HW4.zip [following]
# --2026-02-24 18:21:06--  https://raw.githubusercontent.com/yongsa-nut/SF251_67_2/refs/heads/main/data/HW4.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10007186 (9.5M) [application/zip]
# Saving to: ‘HW4.zip’
#
# HW4.zip             100%[===================>]   9.54M  30.3MB/s    in 0.3s
#
# 2026-02-24 18:21:07 (30.3 MB/s) - ‘HW4.zip’ saved [10007186/10007186]
#
# Archive:  HW4.zip
#    creating: HW4/
#   inflating: HW4/msft_bloomberg_news.txt
#   inflating: HW4/TSE Training ENG - Sheet1.csv
#   inflating: HW4/TSE Training THAI - Sheet1.csv

# %%
TSE_Thai = pd.read_csv("HW4/TSE Training THAI - Sheet1.csv")
TSE_Eng = pd.read_csv("HW4/TSE Training ENG - Sheet1.csv")

# %%
# Check the data. It's small so we can print the whole thing
TSE_Thai
# Out:
#    Group  \
# 0   Thai
# 1   Thai
# 2   Thai
# 3   Thai
# 4   Thai
# 5   Thai
# 6   Thai
# 7   Thai
# 8   Thai
# 9   Thai
# 10  Thai
#
#    ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [การเสวนาหัวข้อ Intro to Modern IT]  \
# 0                                              2 เฉยๆ
# 1                                             5 ดีมาก
# 2                                                4 ดี
# 3                                             5 ดีมาก
# 4                                                4 ดี
# 5                                             5 ดีมาก
# 6                                                4 ดี
# 7                                             5 ดีมาก
# 8                                             5 ดีมาก
# 9                                             5 ดีมาก
# 10                                               4 ดี
#
#    ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [หัวข้อ TSE Showcase ]  \
# 0                                                4 ดี
# 1                                             5 ดีมาก
# 2                                             5 ดีมาก
# 3                                             5 ดีมาก
# 4                                                4 ดี
# 5                                             5 ดีมาก
# 6                                                4 ดี
# 7                                             5 ดีมาก
# 8                                             5 ดีมาก
# 9                                             5 ดีมาก
# 10                                            5 ดีมาก
#
#    ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [การดูงานนอกสถานที่]  \
# 0                                              2 เฉยๆ
# 1                                             5 ดีมาก
# 2                                             5 ดีมาก
# 3                                             5 ดีมาก
# 4                                             5 ดีมาก
# 5                                                4 ดี
# 6                                              2 เฉยๆ
# 7                                             5 ดีมาก
# 8                                             5 ดีมาก
# 9                                             5 ดีมาก
# 10                                            5 ดีมาก
#
#    ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [กิจกรรม Workshop]  \
# 0                                             5 ดีมาก
# 1                                             5 ดีมาก
# 2                                             5 ดีมาก
# 3                                             5 ดีมาก
# 4                                                4 ดี
# 5                                                4 ดี
# 6                                                4 ดี
# 7                                             5 ดีมาก
# 8                                                4 ดี
# 9                                             5 ดีมาก
# 10                                            5 ดีมาก
#
#    ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [การถ่ายทอดของผู้สอน/ผู้บรรยาย ]  \
# 0                                           3 ปานกลาง
# 1                                             5 ดีมาก
# 2                                             5 ดีมาก
# 3                                             5 ดีมาก
# 4                                                4 ดี
# 5                                                4 ดี
# 6                                                4 ดี
# 7                                             5 ดีมาก
# 8                                                4 ดี
# 9                                             5 ดีมาก
# 10                                            5 ดีมาก
#
#    ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [ผลที่่ได้รับที่ได้รับจากการอบรม ตรงตามที่คาดหวัง]  \
# 0                                                4 ดี
# 1                                             5 ดีมาก
# 2                                             5 ดีมาก
# 3                                             5 ดีมาก
# 4                                                4 ดี
# 5                                             5 ดีมาก
# 6                                           3 ปานกลาง
# 7                                             5 ดีมาก
# 8                                             5 ดีมาก
# 9                                             5 ดีมาก
# 10                                            5 ดีมาก
#
#    ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [เจ้าหน้าที่]  \
# 0                                             5 ดีมาก
# 1                                             5 ดีมาก
# 2                                             5 ดีมาก
# 3                                             5 ดีมาก
# 4                                             5 ดีมาก
# 5                                             5 ดีมาก
# 6                                                4 ดี
# 7                                             5 ดีมาก
# 8                                             5 ดีมาก
# 9                                             5 ดีมาก
# 10                                            5 ดีมาก
#
#    ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [อาหารและเครื่องดื่ม]  \
# 0                                              2 เฉยๆ
# 1                                             5 ดีมาก
# 2                                             5 ดีมาก
# 3                                           3 ปานกลาง
# 4                                             5 ดีมาก
# 5                                             5 ดีมาก
# 6                                           3 ปานกลาง
# 7                                             5 ดีมาก
# 8                                             5 ดีมาก
# 9                                             5 ดีมาก
# 10                                          3 ปานกลาง
#
#    ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [ความพึงพอใจในภาพรวมจากการอบรม]
# 0                                                4 ดี
# 1                                             5 ดีมาก
# 2                                             5 ดีมาก
# 3                                             5 ดีมาก
# 4                                             5 ดีมาก
# 5                                             5 ดีมาก
# 6                                                4 ดี
# 7                                             5 ดีมาก
# 8                                             5 ดีมาก
# 9                                             5 ดีมาก
# 10                                               4 ดี

# %%
TSE_Eng
# Out:
#      Group The statements [Session of Intro. to Modern IT ]  \
# 0  English                                          4 Agree
# 1  English                                      5 Excellent
# 2  English                                      5 Excellent
# 3  English                                      5 Excellent
# 4  English                                          4 Agree
# 5  English                                      5 Excellent
# 6  English                                          4 Agree
# 7  English                                      5 Excellent
# 8  English                                      5 Excellent
#
#   The statements [TSE Showcase session] The statements [Filed Trip ]  \
# 0                           5 Excellent                  5 Excellent
# 1                           5 Excellent                  5 Excellent
# 2                           5 Excellent                      4 Agree
# 3                               4 Agree                     3 Neural
# 4                              3 Neural                  5 Excellent
# 5                               4 Agree                  5 Excellent
# 6                           5 Excellent                  5 Excellent
# 7                           5 Excellent                      4 Agree
# 8                           5 Excellent                      4 Agree
#
#   The statements [Workshop activity]  \
# 0                        5 Excellent
# 1                        5 Excellent
# 2                            4 Agree
# 3                            4 Agree
# 4                            4 Agree
# 5                        5 Excellent
# 6                        5 Excellent
# 7                        5 Excellent
# 8                        5 Excellent
#
#   The statements [The instructors/lecturers are performance.]  \
# 0                                            4 Agree
# 1                                        5 Excellent
# 2                                            4 Agree
# 3                                        5 Excellent
# 4                                            4 Agree
# 5                                        5 Excellent
# 6                                            4 Agree
# 7                                        5 Excellent
# 8                                        5 Excellent
#
#   The statements [The TSE training objectives were met.]  \
# 0                                        5 Excellent
# 1                                        5 Excellent
# 2                                            4 Agree
# 3                                        5 Excellent
# 4                                            4 Agree
# 5                                        5 Excellent
# 6                                        5 Excellent
# 7                                        5 Excellent
# 8                                        5 Excellent
#
#   The statements [Staff ] The statements [Food and beverage]  \
# 0             5 Excellent                        5 Excellent
# 1             5 Excellent                        5 Excellent
# 2             5 Excellent                        5 Excellent
# 3             5 Excellent                        5 Excellent
# 4             5 Excellent                            4 Agree
# 5             5 Excellent                            4 Agree
# 6             5 Excellent                            4 Agree
# 7             5 Excellent                            4 Agree
# 8             5 Excellent                            4 Agree
#
#   The statements [The overall satisfaction with the training.]
# 0                                            4 Agree
# 1                                        5 Excellent
# 2                                            4 Agree
# 3                                        5 Excellent
# 4                                        5 Excellent
# 5                                        5 Excellent
# 6                                            4 Agree
# 7                                        5 Excellent
# 8                                        5 Excellent

# %% [markdown]
# ### Q2a เปลี่ยนชื่อ columns
#
# เริ่มแรกเราจะเปลี่ยนชื่อ columns ที่เราต้องการให้สั้นๆ และเหมือนกันทั้งสอง dataset
# เราจะเปลี่ยนสามข้อต่อไปนี้ เป็นดังนี้
#
# 1. "ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [กิจกรรม Workshop]"/"The statements [Workshop activity]" เป็น `"Workshop"`
#
# 2. "ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [การถ่ายทอดของผู้สอน/ผู้บรรยาย ]"/"The statements [The instructors/lecturers are performance.]" เป็น `"Instructors"`
#
# 3. "ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [ผลที่่ได้รับที่ได้รับจากการอบรม ตรงตามที่คาดหวัง]"/"The statements [The TSE training objectives were met.]" เป็น `"Expectation"`

# %%
TSE_Thai = TSE_Thai.rename(columns={'ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [กิจกรรม Workshop]':'Workshop',
                                    'ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [การถ่ายทอดของผู้สอน/ผู้บรรยาย ]':'Instructors',
                                    'ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [ผลที่่ได้รับที่ได้รับจากการอบรม ตรงตามที่คาดหวัง]':'Expectation'})
TSE_Thai
# Out:
#    Group  \
# 0   Thai
# 1   Thai
# 2   Thai
# 3   Thai
# 4   Thai
# 5   Thai
# 6   Thai
# 7   Thai
# 8   Thai
# 9   Thai
# 10  Thai
#
#    ความพึงพอใจในกิจกรรม (5 ดีมาก >>1 ควรปรับปรุง) [การเสวนาหัวข้อ Intro to Modern IT]  \
# 0                                              2 เฉยๆ
# 1                                             5 ดีมาก
# 2                                                4 ดี
# 3                                             5 ดีมาก
# 4                                                4 ดี
# 5                                             5 ดีมาก
# 6                                                4 ดี
# 7                                             5 ดีมาก
# 8                                             5 ดีมาก
# 9                                             5 ดีมาก
# 10                
# 18  English  5 Excellent  5 Excellent  5 Excellent
# 19  English  5 Excellent  5 Excellent  5 Excellent

# %% [markdown]
# ### Q2c Clean up string
#
# ขั้นถัดไปเราจะต้องมาจัดค่าคำตอบซึ่งตอนนี้ จะประกอบไปด้วย ตัวเลขตามตัวคำที่เป็นภาษาอังกฤษหรือไทย เช่น "5 ดีมาก" หรือ "5 Excellent"
#
# ให้เปลี่ยนค่า ของ `Workshop`, `Instructors`, และ `Expectation` ให้เหลือตัวเลขเท่านั้น

# %%
cols = ['Workshop','Instructors','Expectation']

TSE_all[cols] = (
    TSE_all[cols]
    .fillna('0')            # แก้ NaN ก่อน
    .astype(str)            # ทำให้ทุกค่าเป็น string
    .apply(lambda x: x.str.split().str[0])
    .astype(int)            # ค่อยแปลงเป็น int
)
TSE_all
# Out:
#       Group  Workshop  Instructors  Expectation
# 0      Thai         5            3            4
# 1      Thai         5            5            5
# 2      Thai         5            5            5
# 3      Thai         5            5            5
# 4      Thai         4            4            4
# 5      Thai         4            4            5
# 6      Thai         4            4            3
# 7      Thai         5            5            5
# 8      Thai         4            4            5
# 9      Thai         5            5            5
# 10     Thai         5            5            5
# 11  English         5            4            5
# 12  English         5            5            5
# 13  English         4            4            4
# 14  English         4            5            5
# 15  English         4            4            4
# 16  English         5            5            5
# 17  English         5            4            5
# 18  English         5            5            5
# 19  English         5            5            5

# %% [markdown]
# ### Q2d Wide data to Long data
#
# ตอนนี้ Data ของเราเป็น Wide format  ทำให้ไม่สามารถ ใช้ plot ด้วย ggplot ได้ตรงๆ
# เราจะต้องมีการปรับเปลี่ยน Data ให้เป็น Long format ก่อน โดยที่ข้อมูลใหม่จะมี 3 columns ดังนี้
# - Group
# - Question
# - Rating
#
# จงเปลี่ยน `TSE_all` ตอนนี้ให้เป็นรูปแบบที่กำหนด และเก็บค่าไว้ใน `TSE_all_long`

# %%
TSE_all_long = pd.melt(
    TSE_all,
    id_vars='Group',                        # คอลัมน์ที่ไม่เปลี่ยน
    value_vars=['Workshop','Instructors','Expectation'],  # คอลัมน์ที่จะรวม
    var_name='Question',                    # ชื่อคอลัมน์ใหม่
    value_name='Rating'                     # ชื่อค่าคะแนน
)
TSE_all_long
# Out:
#       Group     Question  Rating
# 0      Thai     Workshop       5
# 1      Thai     Workshop       5
# 2      Thai     Workshop       5
# 3      Thai     Workshop       5
# 4      Thai     Workshop       4
# 5      Thai     Workshop       4
# 6      Thai     Workshop       4
# 7      Thai     Workshop       5
# 8      Thai     Workshop       4
# 9      Thai     Workshop       5
# 10     Thai     Workshop       5
# 11  English     Workshop       5
# 12  English     Workshop       5
# 13  English     Workshop       4
# 14  English     Workshop       4
# 15  English     Workshop       4
# 16  English     Workshop       5
# 17  English     Workshop       5
# 18  English     Workshop       5
# 19  English     Workshop       5
# 20     Thai  Instructors       3
# 21     Thai  Instructors       5
# 22     Thai  Instructors       5
# 23     Thai  Instructors       5
# 24     Thai  Instructors       4
# 25     Thai  Instructors       4
# 26     Thai  Instructors       4
# 27     Thai  Instructors       5
# 28     Thai  Instructors       4
# 29     Thai  Instructors       5
# 30     Thai  Instructors       5
# 31  English  Instructors       4
# 32  English  Instructors       5
# 33  English  Instructors       4
# 34  English  Instructors       5
# 35  English  Instructors       4
# 36  English  Instructors       5
# 37  English  Instructors       4
# 38  English  Instructors       5
# 39  English  Instructors       5
# 40     Thai  Expectation       4
# 41     Thai  Expectation       5
# 42     Thai  Expectation       5
# 43     Thai  Expectation       5
# 44     Thai  Expectation       4
# 45     Thai  Expectation       5
# 46     Thai  Expectation       3
# 47     Thai  Expectation       5
# 48     Thai  Expectation       5
# 49     Thai  Expectation       5
# 50     Thai  Expectation       5
# 51  English  Expectation       5
# 52  English  Expectation       5
# 53  English  Expectation       4
# 54  English  Expectation       5
# 55  English  Expectation       4
# 56  English  Expectation       5
# 57  English  Expectation       5
# 58  English  Expectation       5
# 59  English  Expectation       5

# %% [markdown]
# ### Q2e Boxplot ของทั้งสามคำถาม
#
# จงสร้าง boxplot สำหรับ ที่แกน x เป็น `Workshop`, `Instructors`, และ `Expectation`
#
# **หมายเหตุ**: ต้องเปลี่ยนค่า `Rating` ให้เป็น int ก่อน

# %%
from plotnine import *
TSE_all_long['Rating'] = TSE_all_long['Rating'].astype(int) #หมายเหตุ: ต้องเปลี่ยนค่า Rating ให้เป็น int ก่อน

(
    ggplot(TSE_all_long, aes(x='Question', y='Rating')) +
    geom_boxplot() +
    labs(
        title='Boxplot of Ratings',
        x='Question',
        y='Rating'
    )
)

# %% [markdown]
# ### Q2f Boxplot ของทั้งสามคำถาม x Group
#
# สร้าง boxplot ที่เหมาะสม สำหรับการเปรียบเทียบ ระหว่างกลุ่มภาษาไทยกับภาษาอังกฤษ (`Group`) ของทั้งสามคำถาม (`Workshop`, `Instructors`, และ `Expectation`)

# %%
from plotnine import *

(
    ggplot(TSE_all_long, aes(x='Group', y='Rating', fill='Group')) +
    geom_boxplot() +
    facet_wrap('~Question') +
    labs(
        title='Boxplot of Ratings by Group',
        x='Group',
        y='Rating'
    )+
    theme_minimal()
)

# %% [markdown]
# ### Q2g หาค่า Mean ของแต่ละค่า
#
# ถัดไป เราอยากรู้ค่าเฉลี่ยของแต่ละตัวแปรมีค่าเท่าไร
#
# จงสร้าง DataFrame อันใหม่ที่มีสอง columns:
#
# - Question
# - Rating ที่เป็น ค่า Mean
#
# และเก็บค่าไว้ที่ `TSE_all_mean`

# %%
TSE_all_mean = (
    TSE_all_long
        .groupby('Question')
        ['Rating'].mean()
        .reset_index()
)
TSE_all_mean
# Out:
#       Question  Rating
# 0  Expectation    4.70
# 1  Instructors    4.50
# 2     Workshop    4.65

# %% [markdown]
# # Submission
# - File > Download > Download .ipynb
# - Upload to MS Teams
